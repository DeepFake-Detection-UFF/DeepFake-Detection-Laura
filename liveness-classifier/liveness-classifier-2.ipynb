# %% [markdown]
# ## Setup

# %%
# !pip install protobuf==3.20.3
# !pip install lz4
# !pip uninstall mediapipe -y
# !pip install mediapipe
# !pip install retina-face
# !pip install MTCNN
# !pip install ultralytics opencv-python numpy
# !pip install dlib
# !pip install supervision
# !pip install opencv-python-headless
# Out:
# Requirement already satisfied: protobuf==3.20.3 in /usr/local/lib/python3.10/dist-packages (3.20.3)
# Collecting lz4
#   Downloading lz4-4.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Downloading lz4-4.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.0 MB/s eta 0:00:0000:010:01
# Installing collected packages: lz4
# Successfully installed lz4-4.4.3
# WARNING: Skipping mediapipe as it is not installed.
# Collecting mediapipe
#   Downloading mediapipe-0.10.21-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (25.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.5)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.10.0.84)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<2->mediapipe) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<2->mediapipe) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<2->mediapipe) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<2->mediapipe) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<2->mediapipe) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<2->mediapipe) (2.4.1)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<2->mediapipe) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<2->mediapipe) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<2->mediapipe) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<2->mediapipe) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<2->mediapipe) (2024.2.0)
# Downloading mediapipe-0.10.21-cp310-cp310-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 42.6 MB/s eta 0:00:00:00:0100:01
# Downloading protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 13.2 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 1.34.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 4.25.6 which is incompatible.
# google-cloud-bigtable 2.27.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# Successfully installed mediapipe-0.10.21 protobuf-4.25.6 sounddevice-0.5.1
# Collecting retina-face
#   Downloading retina_face-0.0.17-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from retina-face) (1.26.4)
# Requirement already satisfied: gdown>=3.10.1 in /usr/local/lib/python3.10/dist-packages (from retina-face) (5.2.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from retina-face) (11.0.0)
# Requirement already satisfied: opencv-python>=3.4.4 in /usr/local/lib/python3.10/dist-packages (from retina-face) (4.10.0.84)
# Requirement already satisfied: tensorflow>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from retina-face) (2.17.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->retina-face) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->retina-face) (3.17.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->retina-face) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown>=3.10.1->retina-face) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->retina-face) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->retina-face) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->retina-face) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->retina-face) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->retina-face) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->retina-face) (2.4.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=1.9.0->retina-face) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->retina-face) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=1.9.0->retina-face) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=1.9.0->retina-face) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=1.9.0->retina-face) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=1.9.0->retina-face) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=1.9.0->retina-face) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=1.9.0->retina-face) (3.1.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=3.10.1->retina-face) (2.6)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.14.0->retina-face) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.14.0->retina-face) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.14.0->retina-face) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.14.0->retina-face) (2024.2.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown>=3.10.1->retina-face) (1.7.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.14.0->retina-face) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow>=1.9.0->retina-face) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow>=1.9.0->retina-face) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow>=1.9.0->retina-face) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow>=1.9.0->retina-face) (0.1.2)
# Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Installing collected packages: retina-face
# Successfully installed retina-face-0.0.17
# Collecting MTCNN
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from MTCNN) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in /usr/local/lib/python3.10/dist-packages (from MTCNN) (4.4.3)
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 20.7 MB/s eta 0:00:0000:010:01
# Installing collected packages: MTCNN
# Successfully installed MTCNN-1.0.0
# Collecting ultralytics
#   Downloading ultralytics-8.3.90-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.90-py3-none-any.whl (949 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.1/949.1 kB 14.2 MB/s eta 0:00:00a 0:00:01
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.90 ultralytics-thop-2.0.14
# Requirement already satisfied: dlib in /usr/local/lib/python3.10/dist-packages (19.24.2)
# Collecting supervision
#   Downloading supervision-0.25.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from supervision) (1.3.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from supervision) (3.7.5)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from supervision) (1.26.4)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.10/dist-packages (from supervision) (4.10.0.84)
# Requirement already satisfied: pillow>=9.4 in /usr/local/lib/python3.10/dist-packages (from supervision) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from supervision) (6.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from supervision) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from supervision) (1.13.1)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.10/dist-packages (from supervision) (4.67.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6.0->supervision) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->supervision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->supervision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->supervision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->supervision) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->supervision) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->supervision) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->supervision) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->supervision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->supervision) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->supervision) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.2->supervision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.2->supervision) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->supervision) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.2->supervision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.2->supervision) (2024.2.0)
# Downloading supervision-0.25.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: supervision
# Successfully installed supervision-0.25.1
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python-headless) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python-headless) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python-headless) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python-headless) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python-headless) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python-headless) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.2->opencv-python-headless) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.2->opencv-python-headless) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-python-headless) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-python-headless) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.2->opencv-python-headless) (2024.2.0)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2 
import torch
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Input, TimeDistributed, GlobalAveragePooling2D, LSTM, Dense 
from tensorflow.keras.applications import ResNet50 
import time 
import mediapipe as mp
import datetime
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from retinaface import RetinaFace
import tensorflow as tf
from huggingface_hub import hf_hub_download
from ultralytics import YOLO
from supervision import Detections
from mtcnn import MTCNN
import dlib
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, roc_auc_score
import tempfile
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# /kaggle/input/caffe-face-detector-opencv-pretrained-model/weights.caffemodel
# /kaggle/input/caffe-face-detector-opencv-pretrained-model/architecture.txt
# /kaggle/input/celebe-real/id1_0006.mp4
# /kaggle/input/celebe-real/id0_0005.mp4
# /kaggle/input/celebe-real/id0_0008.mp4
# /kaggle/input/celebe-real/id3_0008.mp4
# /kaggle/input/celebe-real/id2_0007.mp4
# /kaggle/input/celebe-real/id2_0000.mp4
# /kaggle/input/celebe-real/id3_0004.mp4
# /kaggle/input/celebe-real/id4_0002.mp4
# /kaggle/input/celebe-real/id0_0009.mp4
# /kaggle/input/celebe-real/id2_0006.mp4
# /kaggle/input/celebe-real/id1_0008.mp4
# /kaggle/input/celebe-real/id2_0002.mp4
# /kaggle/input/celebe-real/id4_0003.mp4
# /kaggle/input/celebe-real/id1_0001.mp4
# /kaggle/input/celebe-real/id0_0002.mp4
# /kaggle/input/celebe-real/id3_0000.mp4
# /kaggle/input/celebe-real/id0_0001.mp4
# /kaggle/input/celebe-real/id3_0003.mp4
# /kaggle/input/celebe-real/id1_0004.mp4
# /kaggle/input/celebe-real/id3_0009.mp4
# /kaggle/input/celebe-real/id3_0006.mp4
# /kaggle/input/celebe-real/id4_0000.mp4
# /kaggle/input/celebe-real/id3_0007.mp4
# /kaggle/input/celebe-real/id3_0005.mp4
# /kaggle/input/celebe-real/id1_0009.mp4
# /kaggle/input/celebe-real/id2_0009.mp4
# /kaggle/input/celebe-real/id4_0008.mp4
# /kaggle/input/celebe-real/id2_0008.mp4
# /kaggle/input/celebe-real/id1_0000.mp4
# /kaggle/input/celebe-real/id0_0006.mp4
# /kaggle/input/celebe-real/id3_0002.mp4
# /kaggle/input/celebe-real/id0_0000.mp4
# /kaggle/input/celebe-real/id2_0001.mp4
# /kaggle/input/celebe-real/id2_0005.mp4
# /kaggle/input/celebe-real/id1_0007.mp4
# /kaggle/input/celebe-real/id1_0005.mp4
# /kaggle/input/celebe-real/id2_0003.mp4
# /kaggle/input/celebe-real/id4_0006.mp4
# /kaggle/input/celebe-real/id0_0003.mp4
# /kaggle/input/celebe-real/id0_0004.mp4
# /kaggle/input/celebe-real/id3_0001.mp4
# /kaggle/input/celebe-real/id1_0002.mp4
# /kaggle/input/celebe-real/id4_0007.mp4
# /kaggle/input/celebe-real/id0_0007.mp4
# /kaggle/input/celebe-real/id2_0004.mp4
# /kaggle/input/celebe-real/id4_0004.mp4
# /kaggle/input/celebe-real/id1_0003.mp4
# /kaggle/input/celebe-real/id4_0001.mp4
# /kaggle/input/celebe-real/id4_0005.mp4
# /kaggle/input/celebe-real/id4_0009.mp4
# /kaggle/input/liveness_classifier/tensorflow2/default/1/resnet_model.h5
# /kaggle/input/celeb-fake/id0_id3_0009.mp4
# /kaggle/input/celeb-fake/id0_id2_0008.mp4
# /kaggle/input/celeb-fake/id0_id4_0003.mp4
# /kaggle/input/celeb-fake/id0_id4_0004.mp4
# /kaggle/input/celeb-fake/id0_id2_0009.mp4
# /kaggle/input/celeb-fake/id0_id9_0007.mp4
# /kaggle/input/celeb-fake/id0_id3_0005.mp4
# /kaggle/input/celeb-fake/id0_id9_0000.mp4
# /kaggle/input/celeb-fake/id0_id2_0004.mp4
# /kaggle/input/celeb-fake/id0_id2_0007.mp4
# /kaggle/input/celeb-fake/id0_id3_0001.mp4
# /kaggle/input/celeb-fake/id0_id4_0000.mp4
# /kaggle/input/celeb-fake/id0_id2_0000.mp4
# /kaggle/input/celeb-fake/id0_id4_0002.mp4
# /kaggle/input/celeb-fake/id0_id9_0006.mp4
# /kaggle/input/celeb-fake/id0_id1_0002.mp4
# /kaggle/input/celeb-fake/id0_id3_0007.mp4
# /kaggle/input/celeb-fake/id0_id9_0002.mp4
# /kaggle/input/celeb-fake/id0_id3_0003.mp4
# /kaggle/input/celeb-fake/id0_id6_0007.mp4
# /kaggle/input/celeb-fake/id0_id6_0009.mp4
# /kaggle/input/celeb-fake/id0_id1_0000.mp4
# /kaggle/input/celeb-fake/id0_id2_0006.mp4
# /kaggle/input/celeb-fake/id0_id2_0002.mp4
# /kaggle/input/celeb-fake/id0_id9_0008.mp4
# /kaggle/input/celeb-fake/id0_id9_0003.mp4
# /kaggle/input/celeb-fake/id0_id6_0002.mp4
# /kaggle/input/celeb-fake/id0_id9_0001.mp4
# /kaggle/input/celeb-fake/id0_id1_0007.mp4
# /kaggle/input/celeb-fake/id0_id3_0004.mp4
# /kaggle/input/celeb-fake/id0_id2_0001.mp4
# /kaggle/input/celeb-fake/id0_id3_0000.mp4
# /kaggle/input/celeb-fake/id0_id6_0001.mp4
# /kaggle/input/celeb-fake/id0_id4_0006.mp4
# /kaggle/input/celeb-fake/id0_id9_0005.mp4
# /kaggle/input/celeb-fake/id0_id1_0003.mp4
# /kaggle/input/celeb-fake/id0_id1_0001.mp4
# /kaggle/input/celeb-fake/id0_id2_0005.mp4
# /kaggle/input/celeb-fake/id0_id3_0002.mp4
# /kaggle/input/celeb-fake/id0_id3_0008.mp4
# /kaggle/input/celeb-fake/id0_id4_0005.mp4
# /kaggle/input/celeb-fake/id0_id4_0001.mp4
# /kaggle/input/celeb-fake/id0_id6_0000.mp4
# /kaggle/input/celeb-fake/id0_id1_0006.mp4
# /kaggle/input/celeb-fake/id0_id1_0009.mp4
# /kaggle/input/celeb-fake/id0_id1_0005.mp4
# /kaggle/input/celeb-fake/id0_id2_0003.mp4
# /kaggle/input/celeb-fake/id0_id6_0006.mp4
# /kaggle/input/celeb-fake/id0_id3_0006.mp4
# /kaggle/input/celeb-fake/id0_id4_0009.mp4
# /kaggle/input/mmod_human_face_detector/other/default/1/mmod_human_face_detector.dat

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Model

# %%
input_shape = (16, 224, 224, 3)

# %%
inputs = Input(shape=input_shape) 
base_model = ResNet50(
    weights='imagenet', 
    include_top=False, 
    input_shape=(224, 224, 3)) 
x = TimeDistributed(base_model)(inputs) 
x = TimeDistributed(GlobalAveragePooling2D())(x) 
x = LSTM(128)(x) 
x = Dense(128, activation='relu')(x) 
outputs = Dense(1, activation='sigmoid')(x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
loaded_model = Model(inputs, outputs) 
loaded_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
loaded_model.load_weights('/kaggle/input/liveness_classifier/tensorflow2/default/1/resnet_model.h5')

# %%
loaded_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 16, 224, 224, 3)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed (TimeDistributed)   │ (None, 16, 7, 7, 2048)      │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_1 (TimeDistributed) │ (None, 16, 2048)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 128)                 │       1,114,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,718,977 (94.30 MB)
#  Trainable params: 24,665,857 (94.09 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %% [markdown]
# ## Preprocessing

# %%
def extract_frames(video_path, process, interval=5, num_frames=16, target_size=(224, 224)):
    cap = cv2.VideoCapture(video_path)
    frames = []
    frame_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if frame_count % interval == 0:
            detected_frame = detect_face(frame, process)
            if detected_frame is not None:
                frames.append(detected_frame)
        
        if len(frames) == num_frames:
            break
        frame_count += 1

    cap.release()

    # Preencher se não tivermos 16 frames
    while len(frames) < num_frames:
        frames.append(frames[-1] if frames else np.zeros((*target_size, 3), dtype=np.uint8))

    return np.array(frames) if frames else None

# %% [markdown]
# ### Extract faces

# %%
def detect_face(frame, process):
    if process == 'haar':
        return extract_face_haar(frame)
    if process == 'mtcnn':
        return extract_face_mtcnn(frame)
    if process == 'yolo':
        return extract_faces_yolo(frame)
    if process == 'ssd':
        return extract_faces_ssd(frame)
    if process == 'dlib':
        return extract_face_dlib(frame)
    if process == 'mediapipe':
        return extract_face_mediapipe(frame)
    
    print(f"Erro: Processo '{process}' não reconhecido")
    return None

# %%
def extract_face_dlib(frame, target_size=(224, 224)):
    dlib.DLIB_USE_CUDA = False 
    detector = dlib.get_frontal_face_detector()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = detector(gray)

    if len(faces) > 0:  # Correção aqui
        face = faces[0]  # Removido `.rect`
        x1, y1, x2, y2 = face.left(), face.top(), face.right(), face.bottom()
        
        h, w = frame.shape[:2]
        x1, y1, x2, y2 = max(0, x1), max(0, y1), min(w, x2), min(h, y2)

        face_img = frame[y1:y2, x1:x2]
        return cv2.resize(face_img, target_size)

    print("Nenhuma face encontrada. Retornando frame original redimensionado. - DLIB")
    return cv2.resize(frame, target_size)

# %%
def extract_face_haar(frame, target_size=(224, 224)):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5, minSize=(30, 30))

    if len(faces) > 0:  # Correção aqui
        x, y, w, h = faces[0]
        face = frame[y:y+h, x:x+w]
        return cv2.resize(face, target_size)

    print("Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR")
    return cv2.resize(frame, target_size)

# %%
# Inicializar o detector de face MTCNN
detector = MTCNN()

def extract_face_mtcnn(frame, target_size=(224, 224)):  
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Converter para RGB
    faces = detector.detect_faces(frame_rgb)

    if faces:
        x, y, w, h = faces[0]['box']  # Pega a primeira face detectada
        x, y = max(0, x), max(0, y)
        face = frame[y:y+h, x:x+w]
        face_resized = cv2.resize(face, target_size)  # Redimensionar
        return face_resized
    
    print("Nenhuma face encontrada. Retornando frame original redimensionado. - MTCNN")
    return cv2.resize(frame, target_size)

# %%
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils
def extract_face_mediapipe(frame, target_size=(224, 224)):    
    with mp_face_detection.FaceDetection(min_detection_confidence=0.5) as face_detection:
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = face_detection.process(frame_rgb)  # Correção aqui

        if results and results.detections:  # Verificação corrigida
            detection = results.detections[0]
            bboxC = detection.location_data.relative_bounding_box
            h, w, _ = frame.shape
            x1, y1 = int(bboxC.xmin * w), int(bboxC.ymin * h)
            x2, y2 = int((bboxC.xmin + bboxC.width) * w), int((bboxC.ymin + bboxC.height) * h)
            
            x1, y1, x2, y2 = max(0, x1), max(0, y1), min(w, x2), min(h, y2)
            face = frame[y1:y2, x1:x2]
            face_resized = cv2.resize(face, target_size)
            return face_resized
    
    print("Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe")
    return cv2.resize(frame, target_size)

# %%
def extract_faces_ssd(frame, target_size=(224, 224)):
    model_path = "/kaggle/input/caffe-face-detector-opencv-pretrained-model/"
    prototxt = model_path + "architecture.txt"
    weights = model_path + "weights.caffemodel"
    
    net = cv2.dnn.readNetFromCaffe(prototxt, weights)

    (h, w) = frame.shape[:2]
    
    blob = cv2.dnn.blobFromImage(frame, scalefactor=1.0, size=(300, 300),
                                 mean=(104.0, 177.0, 123.0), swapRB=False, crop=False)
    
    net.setInput(blob)
    detections = net.forward()

    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        
        if confidence > 0.5:  
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (x1, y1, x2, y2) = box.astype("int")

            x1, y1, x2, y2 = max(0, x1), max(0, y1), min(w - 1, x2), min(h - 1, y2)

            if x2 > x1 and y2 > y1:
                face = frame[y1:y2, x1:x2]  # Recortar a face
                return cv2.resize(face, target_size)

    print("Nenhuma face encontrada. Retornando frame original redimensionado. - SSD")
    return cv2.resize(frame, target_size)

# %%
def extract_faces_yolo(frame, target_size=(224, 224)):
    model_path = hf_hub_download(repo_id="arnabdhar/YOLOv8-Face-Detection", filename="model.pt")
    
    model = YOLO(model_path)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Converter para RGB
    results = model(frame_rgb)[0]
    if len(results.boxes) > 0:
        x1, y1, x2, y2 = map(int, results.boxes.xyxy[0])

        h, w, _ = frame.shape
        x1, y1, x2, y2 = max(0, x1), max(0, y1), min(w, x2), min(h, y2)

        face = frame[y1:y2, x1:x2]
        return cv2.resize(face, target_size)

    print("Nenhuma face encontrada. Retornando frame original redimensionado. - DLIB")
    return cv2.resize(frame, target_size)

# %% [markdown]
# ## Predict class

# %%
def predict_video_class(video_path, model, extract_face):
    frames = extract_frames(video_path, extract_face)  

    if frames is None or len(frames) == 0:
        print(f"Erro: Nenhum frame extraído de {video_path}")
        return None, None

    frames = np.array(frames) / 255.0 
    frames = np.expand_dims(frames, axis=0)  
    
    prediction = model.predict(frames)

    prob_deepfake = prediction[0][0] 

    threshold = 0.5
    pred_label = "Real" if prob_deepfake >= threshold else "Deepfake"

    return pred_label, prob_deepfake

# %% [markdown]
# ### Predict Fake

# %%
video_path = "kaggle/input/celeb-fake/id0_id3_0009.mp4"
predict_video_class(video_path, loaded_model,'yolo')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 31s 31s/step
# ('Real', 0.82483137)

# %%
video_path = "kaggle/input/celeb-fake/id0_id3_0009.mp4"
predict_video_class(video_path, loaded_model,'ssd')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ('Real', 0.82483137)

# %% [markdown]
# ### Predict Real

# %%
video_path = "/kaggle/input/celebe-real/id3_0001.mp4"
predict_video_class(video_path, loaded_model,'yolo')
# Out:
# model.pt:   0%|          | 0.00/6.25M [00:00<?, ?B/s]
# 0: 608x640 1 FACE, 268.1ms
# Speed: 11.9ms preprocess, 268.1ms inference, 17.8ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 139.2ms
# Speed: 3.2ms preprocess, 139.2ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 141.6ms
# Speed: 3.2ms preprocess, 141.6ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 139.6ms
# Speed: 3.2ms preprocess, 139.6ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 140.5ms
# Speed: 3.2ms preprocess, 140.5ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 140.1ms
# Speed: 3.4ms preprocess, 140.1ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 138.9ms
# Speed: 3.3ms preprocess, 138.9ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 140.0ms
# Speed: 3.3ms preprocess, 140.0ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 137.9ms
# Speed: 3.2ms preprocess, 137.9ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 136.8ms
# Speed: 3.1ms preprocess, 136.8ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 145.6ms
# Speed: 3.2ms preprocess, 145.6ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 137.9ms
# Speed: 3.6ms preprocess, 137.9ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 138.3ms
# Speed: 3.4ms preprocess, 138.3ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 138.9ms
# Speed: 3.2ms preprocess, 138.9ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 137.1ms
# Speed: 3.4ms preprocess, 137.1ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 132.9ms
# Speed: 3.0ms preprocess, 132.9ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ('Real', 0.5527471)

# %%
video_path = "kaggle/input/celeb-fake/id0_id3_0009.mp4"
predict_video_class(video_path, loaded_model,'ssd')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ('Real', 0.82483137)

# %% [markdown]
# ## Evaluate videos - Extract faces

# %%
def evaluate_videos(video_dir, extract_face):
    print(extract_face)
    initial_time = datetime.datetime.now()
    print(f"Start at {initial_time.strftime('%d-%m-%Y %H:%M:%S')}")
    
    true_labels = []
    pred_labels = []
    pred_probs = []  

    for class_label in  ["Real", "Deepfake"]:
        class_label_dir = "celebe-real" if class_label == "Real" else "celeb-fake"
        class_dir = os.path.join(video_dir, class_label_dir)
        print(class_dir)

        if not os.path.exists(class_dir):
            continue

        video_files = sorted([f for f in os.listdir(class_dir) if f.endswith(".mp4")])

        for video_file in video_files:
            video_path = os.path.join(class_dir, video_file)
            print(f"\nProcessando: {video_file} ({class_label})")

            # Extração de frames e detecção de deepfake
            label, confidence = predict_video_class(video_path, loaded_model, extract_face)
            
            pred_label = label

            # Salvar rótulos reais e preditos
            true_labels.append(1 if class_label == "Real" else 0)  
            pred_labels.append(1 if pred_label == "Real" else 0)
            pred_probs.append(confidence)

    # Gerar matriz de confusão
    cm = confusion_matrix(true_labels, pred_labels)
    df_cm = pd.DataFrame(cm, index=["Real", "Deepfake"], columns=["Predito Real", "Predito Deepfake"])

    # Exibir matriz de confusão
    plt.figure(figsize=(6, 5))
    sns.heatmap(df_cm, annot=True, fmt="d", cmap="Blues", linewidths=0.5)
    plt.xlabel("Predição")
    plt.ylabel("Real")
    plt.title("Matriz de Confusão - Detecção de Deepfake")
    plt.show()

    # Calcular métricas
    acc = accuracy_score(true_labels, pred_labels)
    f1 = f1_score(true_labels, pred_labels)
    auc = roc_auc_score(true_labels, pred_probs) if len(set(true_labels)) > 1 else None 
    
    # Exibir relatório de classificação
    print("\nRelatório de Classificação:")
    print(classification_report(true_labels, pred_labels, target_names=["Real", "Deepfake"]))
    print(f"Acurácia: {acc:.4f}")
    print(f"F1-score: {f1:.4f}")
    if auc is not None:
        print(f"AUC: {auc:.4f}")
    else:
        print("AUC: Não disponível (apenas uma classe presente nos dados)")

    final_time = datetime.datetime.now()
    duration = final_time - initial_time
    print(f"Finish at {final_time.strftime('%d-%m-%Y %H:%M:%S')}, duration: {duration}")
    
    return acc, f1, auc

# %%
## Diretório de vídeos de teste SSD
video_test_dir = "/kaggle/input/"

# Avaliação de todos os vídeos no diretório
evaluate_videos(video_test_dir, 'ssd')
# Out:
# ssd
# Start at 14-03-2025 15:23:59
# /kaggle/input/celebe-real
#
# Processando: id0_0000.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - SSD
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id1_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# /kaggle/input/celeb-fake
#
# Processando: id0_id1_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id4_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0000.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - SSD
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id9_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#         Real       0.59      0.58      0.59        50
#     Deepfake       0.59      0.60      0.59        50
#
#     accuracy                           0.59       100
#    macro avg       0.59      0.59      0.59       100
# weighted avg       0.59      0.59      0.59       100
#
# Acurácia: 0.5900
# F1-score: 0.5941
# AUC: 0.6188
# Finish at 14-03-2025 15:30:09, duration: 0:06:09.735981
# (0.59, 0.5940594059405941, 0.6187999999999999)

# %%
## Diretório de vídeos de teste DLIB
video_test_dir = "/kaggle/input/"

# Avaliação de todos os vídeos no diretório
evaluate_videos(video_test_dir, 'dlib')
# Out:
# dlib
# Start at 14-03-2025 16:59:01
# /kaggle/input/celebe-real
#
# Processando: id0_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 33s 33s/step
#
# Processando: id0_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id1_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0008.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - DLIB
# Nenhuma face encontrada. Retornando frame original redimensionado. - DLIB
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id2_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id2_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# /kaggle/input/celeb-fake
#
# Processando: id0_id1_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id1_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id4_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id9_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#         Real       0.59      0.48      0.53        50
#     Deepfake       0.56      0.66      0.61        50
#
#     accuracy                           0.57       100
#    macro avg       0.57      0.57      0.57       100
# weighted avg       0.57      0.57      0.57       100
#
# Acurácia: 0.5700
# F1-score: 0.6055
# AUC: 0.6038
# Finish at 14-03-2025 17:16:46, duration: 0:17:45.373258
# (0.57, 0.6055045871559633, 0.6038)

# %%
## Diretório de vídeos de teste YOLO
video_test_dir = "/kaggle/input/"

# Avaliação de todos os vídeos no diretório
evaluate_videos(video_test_dir, 'yolo')
# Out:
# yolo
# Start at 14-03-2025 15:30:09
# /kaggle/input/celebe-real
#
# Processando: id0_0000.mp4 (Real)
#
# 0: 352x640 1 FACE, 106.4ms
# Speed: 2.7ms preprocess, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.0ms
# Speed: 2.8ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 82.9ms
# Speed: 2.7ms preprocess, 82.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 83.9ms
# Speed: 2.7ms preprocess, 83.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.7ms
# Speed: 2.6ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.0ms
# Speed: 2.9ms preprocess, 86.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.7ms
# Speed: 2.7ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.4ms
# Speed: 3.3ms preprocess, 86.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.8ms
# Speed: 2.7ms preprocess, 86.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.8ms
# Speed: 3.2ms preprocess, 85.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.9ms
# Speed: 2.8ms preprocess, 89.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.4ms
# Speed: 2.9ms preprocess, 86.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.7ms
# Speed: 2.6ms preprocess, 84.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.2ms
# Speed: 2.7ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.0ms
# Speed: 2.6ms preprocess, 86.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.7ms
# Speed: 2.8ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0001.mp4 (Real)
#
# 0: 352x640 1 FACE, 87.0ms
# Speed: 2.8ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.6ms
# Speed: 2.7ms preprocess, 85.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.3ms
# Speed: 3.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.7ms
# Speed: 2.4ms preprocess, 90.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.9ms
# Speed: 3.2ms preprocess, 89.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.2ms
# Speed: 2.4ms preprocess, 94.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.8ms
# Speed: 2.7ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 83.4ms
# Speed: 2.9ms preprocess, 83.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.1ms
# Speed: 2.9ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.5ms
# Speed: 2.7ms preprocess, 85.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.7ms
# Speed: 3.4ms preprocess, 84.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.6ms
# Speed: 2.6ms preprocess, 85.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.9ms
# Speed: 2.9ms preprocess, 84.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.9ms
# Speed: 2.7ms preprocess, 84.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 83.0ms
# Speed: 2.7ms preprocess, 83.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.7ms
# Speed: 2.7ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0002.mp4 (Real)
#
# 0: 352x640 1 FACE, 92.3ms
# Speed: 2.3ms preprocess, 92.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.6ms
# Speed: 2.7ms preprocess, 91.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.6ms
# Speed: 2.4ms preprocess, 91.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.3ms
# Speed: 2.4ms preprocess, 93.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.5ms
# Speed: 2.3ms preprocess, 89.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.7ms
# Speed: 3.0ms preprocess, 84.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.0ms
# Speed: 2.3ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.1ms
# Speed: 2.5ms preprocess, 90.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.7ms
# Speed: 2.6ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.2ms
# Speed: 2.4ms preprocess, 91.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.4ms
# Speed: 2.3ms preprocess, 91.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 108.0ms
# Speed: 3.3ms preprocess, 108.0ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 97.4ms
# Speed: 2.5ms preprocess, 97.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.1ms
# Speed: 2.6ms preprocess, 91.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.1ms
# Speed: 2.6ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.6ms
# Speed: 2.3ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0003.mp4 (Real)
#
# 0: 352x640 1 FACE, 90.2ms
# Speed: 2.3ms preprocess, 90.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.5ms
# Speed: 2.4ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.4ms
# Speed: 2.9ms preprocess, 93.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 95.6ms
# Speed: 2.3ms preprocess, 95.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 126.6ms
# Speed: 2.5ms preprocess, 126.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.7ms
# Speed: 2.7ms preprocess, 94.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.4ms
# Speed: 3.1ms preprocess, 91.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 97.6ms
# Speed: 2.9ms preprocess, 97.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 97.1ms
# Speed: 2.6ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.0ms
# Speed: 2.4ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.4ms
# Speed: 2.4ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.7ms
# Speed: 2.6ms preprocess, 86.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.2ms
# Speed: 2.6ms preprocess, 89.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.0ms
# Speed: 2.6ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 104.9ms
# Speed: 2.9ms preprocess, 104.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 95.3ms
# Speed: 2.7ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0004.mp4 (Real)
#
# 0: 352x640 1 FACE, 92.2ms
# Speed: 2.6ms preprocess, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.8ms
# Speed: 2.3ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.3ms
# Speed: 2.4ms preprocess, 93.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.7ms
# Speed: 2.3ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 95.1ms
# Speed: 2.3ms preprocess, 95.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.1ms
# Speed: 2.3ms preprocess, 91.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.6ms
# Speed: 2.3ms preprocess, 90.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.2ms
# Speed: 3.3ms preprocess, 94.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.7ms
# Speed: 3.5ms preprocess, 94.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.3ms
# Speed: 2.3ms preprocess, 89.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.8ms
# Speed: 2.7ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.0ms
# Speed: 2.7ms preprocess, 92.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 95.6ms
# Speed: 3.3ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.0ms
# Speed: 3.2ms preprocess, 91.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.8ms
# Speed: 2.3ms preprocess, 89.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.1ms
# Speed: 3.5ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0005.mp4 (Real)
#
# 0: 352x640 1 FACE, 94.2ms
# Speed: 2.3ms preprocess, 94.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.9ms
# Speed: 2.7ms preprocess, 91.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.5ms
# Speed: 2.6ms preprocess, 92.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.9ms
# Speed: 2.6ms preprocess, 90.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.7ms
# Speed: 2.3ms preprocess, 93.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.0ms
# Speed: 3.3ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.2ms
# Speed: 2.7ms preprocess, 92.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.6ms
# Speed: 3.4ms preprocess, 91.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.3ms
# Speed: 2.7ms preprocess, 92.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.4ms
# Speed: 2.5ms preprocess, 92.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.1ms
# Speed: 2.3ms preprocess, 92.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.7ms
# Speed: 2.3ms preprocess, 93.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.8ms
# Speed: 3.5ms preprocess, 93.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.3ms
# Speed: 2.4ms preprocess, 90.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.5ms
# Speed: 2.4ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.2ms
# Speed: 2.4ms preprocess, 91.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0006.mp4 (Real)
#
# 0: 352x640 1 FACE, 97.8ms
# Speed: 3.5ms preprocess, 97.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.4ms
# Speed: 2.3ms preprocess, 93.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.6ms
# Speed: 2.3ms preprocess, 94.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.5ms
# Speed: 3.2ms preprocess, 91.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 104.5ms
# Speed: 2.4ms preprocess, 104.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.3ms
# Speed: 3.4ms preprocess, 91.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.7ms
# Speed: 2.5ms preprocess, 90.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.3ms
# Speed: 2.6ms preprocess, 87.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.6ms
# Speed: 2.6ms preprocess, 86.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.1ms
# Speed: 2.7ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.6ms
# Speed: 2.8ms preprocess, 86.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.0ms
# Speed: 3.3ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.3ms
# Speed: 2.8ms preprocess, 86.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.1ms
# Speed: 3.1ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 83.2ms
# Speed: 2.8ms preprocess, 83.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.8ms
# Speed: 2.8ms preprocess, 84.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0007.mp4 (Real)
#
# 0: 352x640 2 FACEs, 92.5ms
# Speed: 2.4ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 91.5ms
# Speed: 2.4ms preprocess, 91.5ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 92.1ms
# Speed: 3.3ms preprocess, 92.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 90.7ms
# Speed: 3.1ms preprocess, 90.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 106.9ms
# Speed: 2.3ms preprocess, 106.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 97.2ms
# Speed: 2.3ms preprocess, 97.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 91.7ms
# Speed: 2.9ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 92.7ms
# Speed: 2.3ms preprocess, 92.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.4ms
# Speed: 2.7ms preprocess, 92.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.6ms
# Speed: 2.3ms preprocess, 94.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.4ms
# Speed: 2.3ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.9ms
# Speed: 2.6ms preprocess, 90.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.7ms
# Speed: 2.3ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 94.5ms
# Speed: 2.3ms preprocess, 94.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 91.8ms
# Speed: 2.4ms preprocess, 91.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.9ms
# Speed: 2.4ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0008.mp4 (Real)
#
# 0: 352x640 1 FACE, 92.6ms
# Speed: 2.4ms preprocess, 92.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.3ms
# Speed: 3.5ms preprocess, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.4ms
# Speed: 3.8ms preprocess, 91.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.1ms
# Speed: 2.3ms preprocess, 90.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.4ms
# Speed: 2.3ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.5ms
# Speed: 2.2ms preprocess, 90.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.9ms
# Speed: 2.4ms preprocess, 91.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.2ms
# Speed: 2.5ms preprocess, 89.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.3ms
# Speed: 3.3ms preprocess, 93.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.7ms
# Speed: 2.3ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.6ms
# Speed: 2.6ms preprocess, 91.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.9ms
# Speed: 2.6ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.1ms
# Speed: 2.4ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 97.6ms
# Speed: 2.6ms preprocess, 97.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.0ms
# Speed: 2.4ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.0ms
# Speed: 2.2ms preprocess, 90.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0009.mp4 (Real)
#
# 0: 352x640 1 FACE, 90.3ms
# Speed: 3.6ms preprocess, 90.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.6ms
# Speed: 2.7ms preprocess, 93.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 105.9ms
# Speed: 2.7ms preprocess, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.6ms
# Speed: 2.6ms preprocess, 85.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.9ms
# Speed: 3.0ms preprocess, 85.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.6ms
# Speed: 2.7ms preprocess, 89.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.5ms
# Speed: 3.2ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.4ms
# Speed: 3.1ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.7ms
# Speed: 2.9ms preprocess, 86.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.9ms
# Speed: 3.0ms preprocess, 85.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.7ms
# Speed: 3.3ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.6ms
# Speed: 2.6ms preprocess, 85.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.8ms
# Speed: 3.0ms preprocess, 84.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.1ms
# Speed: 3.2ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.9ms
# Speed: 2.9ms preprocess, 85.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.6ms
# Speed: 2.6ms preprocess, 84.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0000.mp4 (Real)
#
# 0: 576x640 1 FACE, 151.1ms
# Speed: 3.1ms preprocess, 151.1ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 131.5ms
# Speed: 3.0ms preprocess, 131.5ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 131.4ms
# Speed: 3.1ms preprocess, 131.4ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 130.6ms
# Speed: 3.2ms preprocess, 130.6ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 130.2ms
# Speed: 3.0ms preprocess, 130.2ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 131.9ms
# Speed: 3.1ms preprocess, 131.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 130.2ms
# Speed: 3.3ms preprocess, 130.2ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 155.2ms
# Speed: 3.0ms preprocess, 155.2ms inference, 1.9ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 124.1ms
# Speed: 3.6ms preprocess, 124.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 124.4ms
# Speed: 3.4ms preprocess, 124.4ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 126.1ms
# Speed: 3.7ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.5ms
# Speed: 3.3ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 124.0ms
# Speed: 3.3ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.0ms
# Speed: 3.7ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 124.3ms
# Speed: 3.5ms preprocess, 124.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.1ms
# Speed: 3.8ms preprocess, 125.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0001.mp4 (Real)
#
# 0: 608x640 1 FACE, 138.9ms
# Speed: 3.2ms preprocess, 138.9ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 137.9ms
# Speed: 3.3ms preprocess, 137.9ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 132.7ms
# Speed: 3.2ms preprocess, 132.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 132.3ms
# Speed: 3.5ms preprocess, 132.3ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 131.5ms
# Speed: 3.6ms preprocess, 131.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 131.6ms
# Speed: 3.4ms preprocess, 131.6ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 132.0ms
# Speed: 3.6ms preprocess, 132.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 131.5ms
# Speed: 3.6ms preprocess, 131.5ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 137.0ms
# Speed: 3.7ms preprocess, 137.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 134.0ms
# Speed: 3.5ms preprocess, 134.0ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 148.7ms
# Speed: 3.9ms preprocess, 148.7ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 143.9ms
# Speed: 3.3ms preprocess, 143.9ms inference, 1.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 140.7ms
# Speed: 3.2ms preprocess, 140.7ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 143.8ms
# Speed: 3.2ms preprocess, 143.8ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 140.3ms
# Speed: 4.5ms preprocess, 140.3ms inference, 1.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 137.7ms
# Speed: 3.2ms preprocess, 137.7ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0002.mp4 (Real)
#
# 0: 640x640 1 FACE, 159.3ms
# Speed: 3.4ms preprocess, 159.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 137.6ms
# Speed: 3.4ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 135.6ms
# Speed: 3.7ms preprocess, 135.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 137.9ms
# Speed: 3.9ms preprocess, 137.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 137.5ms
# Speed: 3.6ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 140.0ms
# Speed: 3.8ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 136.0ms
# Speed: 3.8ms preprocess, 136.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 138.0ms
# Speed: 3.7ms preprocess, 138.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 137.8ms
# Speed: 3.7ms preprocess, 137.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 136.3ms
# Speed: 3.6ms preprocess, 136.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 138.5ms
# Speed: 3.7ms preprocess, 138.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 141.5ms
# Speed: 3.6ms preprocess, 141.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 139.1ms
# Speed: 3.7ms preprocess, 139.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 139.4ms
# Speed: 3.5ms preprocess, 139.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 139.8ms
# Speed: 3.9ms preprocess, 139.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 140.6ms
# Speed: 3.3ms preprocess, 140.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0003.mp4 (Real)
#
# 0: 544x640 1 FACE, 140.8ms
# Speed: 5.0ms preprocess, 140.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 117.9ms
# Speed: 3.5ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 123.2ms
# Speed: 3.6ms preprocess, 123.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 132.2ms
# Speed: 3.3ms preprocess, 132.2ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 124.6ms
# Speed: 3.9ms preprocess, 124.6ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 125.1ms
# Speed: 3.2ms preprocess, 125.1ms inference, 1.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 128.1ms
# Speed: 3.8ms preprocess, 128.1ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 127.0ms
# Speed: 3.0ms preprocess, 127.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 130.1ms
# Speed: 3.9ms preprocess, 130.1ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 128.1ms
# Speed: 3.2ms preprocess, 128.1ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 127.1ms
# Speed: 3.9ms preprocess, 127.1ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 129.0ms
# Speed: 3.1ms preprocess, 129.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 129.4ms
# Speed: 3.8ms preprocess, 129.4ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 127.8ms
# Speed: 3.0ms preprocess, 127.8ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 127.0ms
# Speed: 3.0ms preprocess, 127.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 129.1ms
# Speed: 3.1ms preprocess, 129.1ms inference, 1.2ms postprocess per image at shape (1, 3, 544, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0004.mp4 (Real)
#
# 0: 640x576 1 FACE, 143.1ms
# Speed: 3.5ms preprocess, 143.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 129.9ms
# Speed: 3.6ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 153.8ms
# Speed: 5.4ms preprocess, 153.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 125.6ms
# Speed: 3.5ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 126.5ms
# Speed: 3.7ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 126.4ms
# Speed: 3.5ms preprocess, 126.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 124.8ms
# Speed: 3.6ms preprocess, 124.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 125.9ms
# Speed: 3.4ms preprocess, 125.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 124.4ms
# Speed: 3.7ms preprocess, 124.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 127.7ms
# Speed: 3.7ms preprocess, 127.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 125.0ms
# Speed: 3.7ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 124.8ms
# Speed: 3.2ms preprocess, 124.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 126.1ms
# Speed: 3.5ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 126.2ms
# Speed: 3.1ms preprocess, 126.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 126.4ms
# Speed: 3.3ms preprocess, 126.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 FACE, 125.3ms
# Speed: 3.2ms preprocess, 125.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0005.mp4 (Real)
#
# 0: 640x640 1 FACE, 148.0ms
# Speed: 3.3ms preprocess, 148.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 142.3ms
# Speed: 3.4ms preprocess, 142.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 144.5ms
# Speed: 3.3ms preprocess, 144.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 144.3ms
# Speed: 3.3ms preprocess, 144.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 235.3ms
# Speed: 3.5ms preprocess, 235.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 154.6ms
# Speed: 4.5ms preprocess, 154.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 154.8ms
# Speed: 5.5ms preprocess, 154.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 146.9ms
# Speed: 3.2ms preprocess, 146.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 147.0ms
# Speed: 4.2ms preprocess, 147.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 145.9ms
# Speed: 3.2ms preprocess, 145.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 148.2ms
# Speed: 3.3ms preprocess, 148.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 143.1ms
# Speed: 4.2ms preprocess, 143.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 142.4ms
# Speed: 3.5ms preprocess, 142.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 143.9ms
# Speed: 3.4ms preprocess, 143.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 143.9ms
# Speed: 3.3ms preprocess, 143.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 144.3ms
# Speed: 3.5ms preprocess, 144.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0006.mp4 (Real)
#
# 0: 576x640 1 FACE, 124.1ms
# Speed: 3.5ms preprocess, 124.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.0ms
# Speed: 3.4ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.5ms
# Speed: 3.6ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 126.0ms
# Speed: 3.2ms preprocess, 126.0ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 126.0ms
# Speed: 3.4ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 126.6ms
# Speed: 3.5ms preprocess, 126.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.6ms
# Speed: 3.9ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 123.8ms
# Speed: 3.4ms preprocess, 123.8ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.5ms
# Speed: 3.3ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 126.1ms
# Speed: 3.6ms preprocess, 126.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.3ms
# Speed: 3.5ms preprocess, 125.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 129.7ms
# Speed: 3.5ms preprocess, 129.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 153.1ms
# Speed: 3.3ms preprocess, 153.1ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 133.1ms
# Speed: 3.3ms preprocess, 133.1ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 132.0ms
# Speed: 3.5ms preprocess, 132.0ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 133.9ms
# Speed: 3.0ms preprocess, 133.9ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0007.mp4 (Real)
#
# 0: 640x640 2 FACEs, 153.6ms
# Speed: 6.1ms preprocess, 153.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 145.8ms
# Speed: 3.6ms preprocess, 145.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 143.9ms
# Speed: 3.3ms preprocess, 143.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 146.2ms
# Speed: 3.3ms preprocess, 146.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 155.5ms
# Speed: 3.4ms preprocess, 155.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 145.0ms
# Speed: 3.5ms preprocess, 145.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 145.7ms
# Speed: 3.2ms preprocess, 145.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 146.5ms
# Speed: 3.2ms preprocess, 146.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 149.9ms
# Speed: 3.3ms preprocess, 149.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 138.3ms
# Speed: 3.5ms preprocess, 138.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 139.9ms
# Speed: 3.8ms preprocess, 139.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 146.8ms
# Speed: 3.7ms preprocess, 146.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 140.2ms
# Speed: 3.7ms preprocess, 140.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 140.5ms
# Speed: 3.9ms preprocess, 140.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 176.3ms
# Speed: 4.1ms preprocess, 176.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 FACEs, 138.3ms
# Speed: 4.0ms preprocess, 138.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0008.mp4 (Real)
#
# 0: 576x640 1 FACE, 127.7ms
# Speed: 3.4ms preprocess, 127.7ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 128.2ms
# Speed: 3.4ms preprocess, 128.2ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 126.3ms
# Speed: 3.8ms preprocess, 126.3ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 127.0ms
# Speed: 3.7ms preprocess, 127.0ms inference, 1.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 127.5ms
# Speed: 3.4ms preprocess, 127.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 126.5ms
# Speed: 3.3ms preprocess, 126.5ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 127.8ms
# Speed: 3.4ms preprocess, 127.8ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 127.0ms
# Speed: 3.6ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.9ms
# Speed: 3.5ms preprocess, 125.9ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 125.8ms
# Speed: 3.5ms preprocess, 125.8ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 127.2ms
# Speed: 3.2ms preprocess, 127.2ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 126.3ms
# Speed: 3.5ms preprocess, 126.3ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 128.1ms
# Speed: 3.6ms preprocess, 128.1ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 126.8ms
# Speed: 3.4ms preprocess, 126.8ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 127.3ms
# Speed: 3.5ms preprocess, 127.3ms inference, 1.1ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 1 FACE, 127.0ms
# Speed: 3.1ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 576, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0009.mp4 (Real)
#
# 0: 640x640 1 FACE, 148.2ms
# Speed: 3.4ms preprocess, 148.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 145.9ms
# Speed: 3.4ms preprocess, 145.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 150.8ms
# Speed: 3.4ms preprocess, 150.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 146.4ms
# Speed: 3.3ms preprocess, 146.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 144.8ms
# Speed: 4.2ms preprocess, 144.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 144.7ms
# Speed: 3.4ms preprocess, 144.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 144.4ms
# Speed: 3.3ms preprocess, 144.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 145.4ms
# Speed: 3.3ms preprocess, 145.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 142.6ms
# Speed: 3.2ms preprocess, 142.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 137.4ms
# Speed: 3.7ms preprocess, 137.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 137.7ms
# Speed: 3.5ms preprocess, 137.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 140.0ms
# Speed: 3.7ms preprocess, 140.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 141.6ms
# Speed: 3.7ms preprocess, 141.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 137.0ms
# Speed: 3.5ms preprocess, 137.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 138.9ms
# Speed: 3.6ms preprocess, 138.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 FACE, 137.7ms
# Speed: 3.5ms preprocess, 137.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0000.mp4 (Real)
#
# 0: 544x640 1 FACE, 117.6ms
# Speed: 3.3ms preprocess, 117.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 118.7ms
# Speed: 3.6ms preprocess, 118.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 118.6ms
# Speed: 3.7ms preprocess, 118.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 124.8ms
# Speed: 3.1ms preprocess, 124.8ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 119.7ms
# Speed: 3.3ms preprocess, 119.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 118.0ms
# Speed: 3.3ms preprocess, 118.0ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 118.5ms
# Speed: 3.5ms preprocess, 118.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 119.6ms
# Speed: 3.3ms preprocess, 119.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 119.2ms
# Speed: 3.3ms preprocess, 119.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 117.9ms
# Speed: 3.1ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 117.3ms
# Speed: 3.3ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 118.6ms
# Speed: 3.3ms preprocess, 118.6ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 117.7ms
# Speed: 3.3ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.7ms
# Speed: 3.3ms preprocess, 120.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.3ms
# Speed: 3.4ms preprocess, 120.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.8ms
# Speed: 3.4ms preprocess, 120.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0001.mp4 (Real)
#
# 0: 544x640 1 FACE, 120.4ms
# Speed: 3.4ms preprocess, 120.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 124.4ms
# Speed: 3.5ms preprocess, 124.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 118.3ms
# Speed: 3.2ms preprocess, 118.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 118.0ms
# Speed: 3.4ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 119.7ms
# Speed: 3.5ms preprocess, 119.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 122.3ms
# Speed: 3.4ms preprocess, 122.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 119.3ms
# Speed: 3.3ms preprocess, 119.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 117.9ms
# Speed: 3.3ms preprocess, 117.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 123.3ms
# Speed: 3.6ms preprocess, 123.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 124.3ms
# Speed: 3.7ms preprocess, 124.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.8ms
# Speed: 3.4ms preprocess, 120.8ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 121.9ms
# Speed: 3.4ms preprocess, 121.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 122.2ms
# Speed: 3.5ms preprocess, 122.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 127.9ms
# Speed: 3.3ms preprocess, 127.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.1ms
# Speed: 3.3ms preprocess, 120.1ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 119.3ms
# Speed: 3.7ms preprocess, 119.3ms inference, 2.5ms postprocess per image at shape (1, 3, 544, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0002.mp4 (Real)
#
# 0: 544x640 1 FACE, 121.7ms
# Speed: 2.7ms preprocess, 121.7ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.4ms
# Speed: 3.0ms preprocess, 120.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 121.0ms
# Speed: 3.4ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 119.2ms
# Speed: 3.6ms preprocess, 119.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 122.1ms
# Speed: 3.5ms preprocess, 122.1ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.4ms
# Speed: 3.3ms preprocess, 120.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.9ms
# Speed: 3.5ms preprocess, 120.9ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 121.3ms
# Speed: 3.3ms preprocess, 121.3ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 119.4ms
# Speed: 3.3ms preprocess, 119.4ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.6ms
# Speed: 3.1ms preprocess, 120.6ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 120.2ms
# Speed: 3.6ms preprocess, 120.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 121.2ms
# Speed: 3.5ms preprocess, 121.2ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 125.5ms
# Speed: 3.4ms preprocess, 125.5ms inference, 1.0ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 138.5ms
# Speed: 4.4ms preprocess, 138.5ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 126.8ms
# Speed: 3.1ms preprocess, 126.8ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 544x640 1 FACE, 128.0ms
# Speed: 3.2ms preprocess, 128.0ms inference, 1.1ms postprocess per image at shape (1, 3, 544, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0003.mp4 (Real)
#
# 0: 608x640 1 FACE, 145.8ms
# Speed: 3.3ms preprocess, 145.8ms inference, 1.1ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 1 FACE, 137.5ms
# ...
#
# 0: 352x640 1 FACE, 88.8ms
# Speed: 2.7ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 95.7ms
# Speed: 2.9ms preprocess, 95.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.2ms
# Speed: 2.8ms preprocess, 86.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.0ms
# Speed: 2.7ms preprocess, 88.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.0ms
# Speed: 2.7ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.0ms
# Speed: 2.8ms preprocess, 89.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 97.1ms
# Speed: 3.0ms preprocess, 97.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0001.mp4 (Deepfake)
#
# 0: 352x640 1 FACE, 87.5ms
# Speed: 2.7ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.2ms
# Speed: 2.8ms preprocess, 89.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.4ms
# Speed: 3.0ms preprocess, 86.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.0ms
# Speed: 3.0ms preprocess, 90.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.4ms
# Speed: 2.8ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.8ms
# Speed: 3.2ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.9ms
# Speed: 2.9ms preprocess, 86.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.0ms
# Speed: 2.8ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.5ms
# Speed: 2.7ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.4ms
# Speed: 3.0ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.1ms
# Speed: 2.8ms preprocess, 87.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.6ms
# Speed: 3.0ms preprocess, 88.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.7ms
# Speed: 2.9ms preprocess, 88.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.6ms
# Speed: 2.8ms preprocess, 90.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.3ms
# Speed: 2.8ms preprocess, 87.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.6ms
# Speed: 2.7ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0002.mp4 (Deepfake)
#
# 0: 352x640 1 FACE, 86.4ms
# Speed: 2.6ms preprocess, 86.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 99.4ms
# Speed: 2.5ms preprocess, 99.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 107.4ms
# Speed: 2.3ms preprocess, 107.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 101.6ms
# Speed: 3.9ms preprocess, 101.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 100.9ms
# Speed: 4.5ms preprocess, 100.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 97.1ms
# Speed: 3.4ms preprocess, 97.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 95.4ms
# Speed: 2.4ms preprocess, 95.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 95.9ms
# Speed: 3.3ms preprocess, 95.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 95.1ms
# Speed: 2.6ms preprocess, 95.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 96.1ms
# Speed: 2.5ms preprocess, 96.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.6ms
# Speed: 2.9ms preprocess, 87.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.8ms
# Speed: 2.6ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.6ms
# Speed: 3.0ms preprocess, 86.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.3ms
# Speed: 2.6ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.7ms
# Speed: 2.8ms preprocess, 86.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.8ms
# Speed: 2.9ms preprocess, 88.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0003.mp4 (Deepfake)
#
# 0: 352x640 1 FACE, 86.7ms
# Speed: 2.7ms preprocess, 86.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.1ms
# Speed: 2.9ms preprocess, 88.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.3ms
# Speed: 3.2ms preprocess, 86.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.6ms
# Speed: 2.8ms preprocess, 85.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.2ms
# Speed: 2.8ms preprocess, 85.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.3ms
# Speed: 3.0ms preprocess, 88.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.5ms
# Speed: 3.2ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.8ms
# Speed: 3.1ms preprocess, 85.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.2ms
# Speed: 2.8ms preprocess, 85.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.4ms
# Speed: 3.0ms preprocess, 84.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.1ms
# Speed: 2.9ms preprocess, 85.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.7ms
# Speed: 2.8ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.2ms
# Speed: 2.9ms preprocess, 88.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.9ms
# Speed: 3.4ms preprocess, 87.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 83.8ms
# Speed: 2.9ms preprocess, 83.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.0ms
# Speed: 3.0ms preprocess, 89.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0005.mp4 (Deepfake)
#
# 0: 352x640 1 FACE, 87.1ms
# Speed: 2.7ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.4ms
# Speed: 3.0ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.0ms
# Speed: 2.8ms preprocess, 89.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.4ms
# Speed: 2.8ms preprocess, 89.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.3ms
# Speed: 2.8ms preprocess, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.8ms
# Speed: 3.0ms preprocess, 85.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.3ms
# Speed: 2.8ms preprocess, 91.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.6ms
# Speed: 2.9ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.9ms
# Speed: 3.1ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.0ms
# Speed: 3.4ms preprocess, 90.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.1ms
# Speed: 2.7ms preprocess, 94.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.1ms
# Speed: 2.8ms preprocess, 92.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.4ms
# Speed: 3.0ms preprocess, 90.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.6ms
# Speed: 2.9ms preprocess, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.7ms
# Speed: 3.1ms preprocess, 86.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.8ms
# Speed: 2.8ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0006.mp4 (Deepfake)
#
# 0: 352x640 1 FACE, 94.1ms
# Speed: 2.5ms preprocess, 94.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.0ms
# Speed: 2.4ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.5ms
# Speed: 2.4ms preprocess, 94.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.1ms
# Speed: 3.4ms preprocess, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.6ms
# Speed: 2.6ms preprocess, 94.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.0ms
# Speed: 2.6ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.0ms
# Speed: 2.5ms preprocess, 94.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.9ms
# Speed: 2.3ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.0ms
# Speed: 3.3ms preprocess, 93.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.5ms
# Speed: 2.6ms preprocess, 92.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.1ms
# Speed: 2.4ms preprocess, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 100.2ms
# Speed: 2.8ms preprocess, 100.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 96.4ms
# Speed: 3.2ms preprocess, 96.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 94.4ms
# Speed: 2.4ms preprocess, 94.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 93.8ms
# Speed: 2.3ms preprocess, 93.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 95.3ms
# Speed: 2.7ms preprocess, 95.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0007.mp4 (Deepfake)
#
# 0: 352x640 1 FACE, 87.6ms
# Speed: 2.8ms preprocess, 87.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.3ms
# Speed: 3.4ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.7ms
# Speed: 3.1ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.2ms
# Speed: 2.8ms preprocess, 89.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 107.5ms
# Speed: 5.6ms preprocess, 107.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 109.2ms
# Speed: 2.3ms preprocess, 109.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 94.2ms
# Speed: 2.3ms preprocess, 94.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 95.7ms
# Speed: 2.6ms preprocess, 95.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 94.8ms
# Speed: 2.3ms preprocess, 94.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.4ms
# Speed: 2.4ms preprocess, 92.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 91.0ms
# Speed: 2.7ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 93.5ms
# Speed: 3.4ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 94.4ms
# Speed: 2.3ms preprocess, 94.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 FACEs, 93.5ms
# Speed: 2.4ms preprocess, 93.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 120.0ms
# Speed: 2.3ms preprocess, 120.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0008.mp4 (Deepfake)
#
# 0: 352x640 1 FACE, 86.0ms
# Speed: 2.7ms preprocess, 86.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.0ms
# Speed: 2.8ms preprocess, 88.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.0ms
# Speed: 2.7ms preprocess, 86.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.5ms
# Speed: 2.9ms preprocess, 86.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.1ms
# Speed: 2.7ms preprocess, 87.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.9ms
# Speed: 3.0ms preprocess, 87.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.9ms
# Speed: 2.7ms preprocess, 85.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.7ms
# Speed: 2.8ms preprocess, 85.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 90.8ms
# Speed: 2.7ms preprocess, 90.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 88.8ms
# Speed: 2.5ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 85.8ms
# Speed: 2.7ms preprocess, 85.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 87.7ms
# Speed: 2.5ms preprocess, 87.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 86.7ms
# Speed: 3.1ms preprocess, 86.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 92.7ms
# Speed: 2.7ms preprocess, 92.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 84.8ms
# Speed: 2.8ms preprocess, 84.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 FACE, 89.4ms
# Speed: 2.7ms preprocess, 89.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#         Real       0.65      0.64      0.65        50
#     Deepfake       0.65      0.66      0.65        50
#
#     accuracy                           0.65       100
#    macro avg       0.65      0.65      0.65       100
# weighted avg       0.65      0.65      0.65       100
#
# Acurácia: 0.6500
# F1-score: 0.6535
# AUC: 0.6576
# Finish at 14-03-2025 15:44:07, duration: 0:13:57.628523
# (0.65, 0.6534653465346535, 0.6576)

# %%
## Diretório de vídeos de teste 
video_test_dir = "/kaggle/input/"

# Avaliação de todos os vídeos no diretório
evaluate_videos(video_test_dir,'mediapipe')
# Out:
# mediapipe
# Start at 14-03-2025 15:44:07
# /kaggle/input/celebe-real
#
# Processando: id0_0000.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id1_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id2_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id3_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# /kaggle/input/celeb-fake
#
# Processando: id0_id1_0000.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id1_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0000.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0000.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0000.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0000.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0000.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# Nenhuma face encontrada. Retornando frame original redimensionado. - Media Pipe
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#         Real       0.64      0.46      0.53        50
#     Deepfake       0.58      0.74      0.65        50
#
#     accuracy                           0.60       100
#    macro avg       0.61      0.60      0.59       100
# weighted avg       0.61      0.60      0.59       100
#
# Acurácia: 0.6000
# F1-score: 0.6491
# AUC: 0.6262
# Finish at 14-03-2025 15:47:37, duration: 0:03:29.926440
# (0.6, 0.6491228070175439, 0.6262)

# %%
## Diretório de vídeos de teste Haar
video_test_dir = "/kaggle/input/"

# Avaliação de todos os vídeos no diretório
evaluate_videos(video_test_dir, 'haar')
# Out:
# haar
# Start at 14-03-2025 15:47:37
# /kaggle/input/celebe-real
#
# Processando: id0_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0003.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0008.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id1_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0003.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0006.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0008.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id2_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0005.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0006.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0007.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id2_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0000.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0008.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0000.mp4 (Real)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id4_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# /kaggle/input/celeb-fake
#
# Processando: id0_id1_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0003.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id1_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0003.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0008.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0003.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0008.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id4_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0003.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id6_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0003.mp4 (Deepfake)
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# Nenhuma face encontrada. Retornando frame original redimensionado. - HAAR
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id9_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#         Real       0.60      0.36      0.45        50
#     Deepfake       0.54      0.76      0.63        50
#
#     accuracy                           0.56       100
#    macro avg       0.57      0.56      0.54       100
# weighted avg       0.57      0.56      0.54       100
#
# Acurácia: 0.5600
# F1-score: 0.6333
# AUC: 0.5964
# Finish at 14-03-2025 15:53:50, duration: 0:06:13.203736
# (0.56, 0.6333333333333332, 0.5964)

# %%
## Diretório de vídeos de teste MTCNN
video_test_dir = "/kaggle/input/"

# Avaliação de todos os vídeos no diretório
evaluate_videos(video_test_dir, 'mtcnn')
# Out:
# mtcnn
# Start at 14-03-2025 15:53:50
# /kaggle/input/celebe-real
#
# Processando: id0_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id1_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id2_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id2_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id3_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id3_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0000.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0001.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id4_0002.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0003.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0004.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0005.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0006.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0007.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0008.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id4_0009.mp4 (Real)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# /kaggle/input/celeb-fake
#
# Processando: id0_id1_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id1_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id2_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id2_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
#
# Processando: id0_id2_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id3_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0004.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id4_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id6_0009.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0000.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0001.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0002.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0003.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0005.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0006.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0007.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Processando: id0_id9_0008.mp4 (Deepfake)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#         Real       0.57      0.54      0.56        50
#     Deepfake       0.57      0.60      0.58        50
#
#     accuracy                           0.57       100
#    macro avg       0.57      0.57      0.57       100
# weighted avg       0.57      0.57      0.57       100
#
# Acurácia: 0.5700
# F1-score: 0.5825
# AUC: 0.6080
# Finish at 14-03-2025 16:05:51, duration: 0:12:00.908371
# (0.57, 0.5825242718446602, 0.608)
